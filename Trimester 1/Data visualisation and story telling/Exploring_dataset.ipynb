# %%
import pandas as pd

df = pd.read_csv('India_VAHAN_Dataset.csv')

print(df.shape)
print(df.head())
print(df.info())
print(df.isnull().sum())
# Out:
# (3700, 13)
#   Registration_Number Registration_Date  Registration_Year           State  \
# 0           REG100001        13-12-2019               2019  Madhya Pradesh
# 1           REG100002        14-01-2020               2020       Karnataka
# 2           REG100003        23-03-2023               2023       Karnataka
# 3           REG100004        26-06-2021               2021       Karnataka
# 4           REG100005        13-11-2022               2022       Karnataka
#
#             RTO_Office Vehicle_Category Vehicle_Sub_Type Manufacturer_Brand  \
# 0       Bhopal (MP-04)               2W          Scooter              Bajaj
# 1      Belgaum (KA-22)               2W       Motorcycle              Honda
# 2  Delhi South (DL-09)               2W          Scooter       Ola Electric
# 3         Kota (RJ-20)               2W          Scooter              Honda
# 4    Ahmedabad (GJ-01)               4W        Hatchback              Honda
#
# ...
